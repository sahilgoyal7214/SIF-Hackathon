# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.preprocessing import MinMaxScaler
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.stattools import adfuller
from tensorflow.keras.models import Sequential, save_model
from tensorflow.keras.layers import LSTM, Dense

# %%
df=pd.read_csv("minimum_temperature.csv")
df["Date"]=pd.to_datetime(df["Date"])
df.set_index('Date', inplace=True)
df
# Out:
#             Temp
# Date
# 1981-01-01  20.7
# 1981-01-02  17.9
# 1981-01-03  18.8
# 1981-01-04  14.6
# 1981-01-05  15.8
# ...          ...
# 1990-12-27  14.0
# 1990-12-28  13.6
# 1990-12-29  13.5
# 1990-12-30  15.7
# 1990-12-31  13.0
#
# [3650 rows x 1 columns]

# %%
df.dtypes
# Out:
# Temp    float64
# dtype: object

# %%
df.isna().sum()
# Out:
# Temp    0
# dtype: int64

# %%
plt.figure(figsize = (7,7))
plt.subplot(2,1,1)
plot_acf(df['Temp'], lags = 40, ax = plt.gca(), title= "ACF Chart")
plt.subplot(2,1,2)
plot_pacf(df['Temp'], lags = 40, ax = plt.gca(), title= "PACF Chart")
plt.show()

# %%
def adf_test(dataset):
  dftest = adfuller(dataset, autolag = 'AIC')
  print("1. ADF : ",dftest[0])
  print("2. P-Value : ", dftest[1])
  print("3. Num Of Lags : ", dftest[2])
  print("4. Num Of Observations Used For ADF Regression and Critical Values Calculation :", dftest[3])
  print("5. Critical Values :")
  for key, val in dftest[4].items():
      print("\t",key, ": ", val)

# %%
adf_test(df["Temp"])
# Out:
# 1. ADF :  -4.444804924611687
# 2. P-Value :  0.00024708263003611164
# 3. Num Of Lags :  20
# 4. Num Of Observations Used For ADF Regression and Critical Values Calculation : 3629
# 5. Critical Values :
# 	 1% :  -3.4321532327220154
# 	 5% :  -2.862336767636517
# 	 10% :  -2.56719413172842

# %%
train_size = int(len(df) * 0.8)
train, test = df.iloc[:train_size], df.iloc[train_size:]

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
train_date = train.index
test_date = test.index

# %%
train_values = train.values.reshape(-1, 1)
test_values = test.values.reshape(-1, 1)

# %%
train_scaled = scaler.fit_transform(train_values)
test_scaled = scaler.transform(test_values)

# %%
train_scaled = train_scaled.reshape(-1, len(train.columns))
test_scaled = test_scaled.reshape(-1, len(test.columns))

# %%
train_scaled_df = pd.DataFrame(train_scaled, columns=train.columns, index=train_date)
test_scaled_df = pd.DataFrame(test_scaled, columns=test.columns, index=test_date)

# %%
def create_sequences(data, sequence_length):
    sequences = []
    for i in range(len(data) - sequence_length + 1):
        seq = data[i:i + sequence_length]
        sequences.append(seq)
    return np.array(sequences)

# %%
sequence_length = 10
X_train = create_sequences(train_scaled_df.values, sequence_length)
X_test = create_sequences(test_scaled_df.values, sequence_length)

# %%
X_train, y_train = X_train[:, :-1], X_train[:, -1][:, -1]
X_test, y_test = X_test[:, :-1], X_test[:, -1][:, -1]

# %%
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_data=(X_test, y_test), verbose=2)
# Out:
# Epoch 1/50
# 91/91 - 1s - loss: 0.0419 - val_loss: 0.0099 - 1s/epoch - 16ms/step
# Epoch 2/50
# 91/91 - 0s - loss: 0.0111 - val_loss: 0.0091 - 328ms/epoch - 4ms/step
# Epoch 3/50
# 91/91 - 0s - loss: 0.0108 - val_loss: 0.0090 - 373ms/epoch - 4ms/step
# Epoch 4/50
# 91/91 - 0s - loss: 0.0106 - val_loss: 0.0088 - 357ms/epoch - 4ms/step
# Epoch 5/50
# 91/91 - 0s - loss: 0.0104 - val_loss: 0.0086 - 362ms/epoch - 4ms/step
# Epoch 6/50
# 91/91 - 0s - loss: 0.0102 - val_loss: 0.0082 - 373ms/epoch - 4ms/step
# Epoch 7/50
# 91/91 - 0s - loss: 0.0099 - val_loss: 0.0080 - 336ms/epoch - 4ms/step
# Epoch 8/50
# 91/91 - 0s - loss: 0.0096 - val_loss: 0.0080 - 322ms/epoch - 4ms/step
# Epoch 9/50
# 91/91 - 0s - loss: 0.0094 - val_loss: 0.0083 - 371ms/epoch - 4ms/step
# Epoch 10/50
# 91/91 - 0s - loss: 0.0092 - val_loss: 0.0074 - 366ms/epoch - 4ms/step
# Epoch 11/50
# 91/91 - 0s - loss: 0.0092 - val_loss: 0.0076 - 375ms/epoch - 4ms/step
# Epoch 12/50
# 91/91 - 0s - loss: 0.0091 - val_loss: 0.0075 - 373ms/epoch - 4ms/step
# Epoch 13/50
# 91/91 - 0s - loss: 0.0091 - val_loss: 0.0072 - 355ms/epoch - 4ms/step
# Epoch 14/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0073 - 378ms/epoch - 4ms/step
# Epoch 15/50
# 91/91 - 0s - loss: 0.0091 - val_loss: 0.0071 - 356ms/epoch - 4ms/step
# Epoch 16/50
# 91/91 - 0s - loss: 0.0091 - val_loss: 0.0074 - 373ms/epoch - 4ms/step
# Epoch 17/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 373ms/epoch - 4ms/step
# Epoch 18/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 374ms/epoch - 4ms/step
# Epoch 19/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 376ms/epoch - 4ms/step
# Epoch 20/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 385ms/epoch - 4ms/step
# Epoch 21/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0072 - 379ms/epoch - 4ms/step
# Epoch 22/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0071 - 369ms/epoch - 4ms/step
# Epoch 23/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 366ms/epoch - 4ms/step
# Epoch 24/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0075 - 362ms/epoch - 4ms/step
# Epoch 25/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 374ms/epoch - 4ms/step
# Epoch 26/50
# 91/91 - 0s - loss: 0.0091 - val_loss: 0.0072 - 358ms/epoch - 4ms/step
# Epoch 27/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0073 - 369ms/epoch - 4ms/step
# Epoch 28/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0073 - 366ms/epoch - 4ms/step
# Epoch 29/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0071 - 386ms/epoch - 4ms/step
# Epoch 30/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 374ms/epoch - 4ms/step
# Epoch 31/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0072 - 352ms/epoch - 4ms/step
# Epoch 32/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 350ms/epoch - 4ms/step
# Epoch 33/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0072 - 372ms/epoch - 4ms/step
# Epoch 34/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0070 - 381ms/epoch - 4ms/step
# Epoch 35/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0075 - 412ms/epoch - 5ms/step
# Epoch 36/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0074 - 414ms/epoch - 5ms/step
# Epoch 37/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0070 - 381ms/epoch - 4ms/step
# Epoch 38/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 360ms/epoch - 4ms/step
# Epoch 39/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0071 - 370ms/epoch - 4ms/step
# Epoch 40/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0070 - 413ms/epoch - 5ms/step
# Epoch 41/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0070 - 355ms/epoch - 4ms/step
# Epoch 42/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0070 - 371ms/epoch - 4ms/step
# Epoch 43/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 347ms/epoch - 4ms/step
# Epoch 44/50
# 91/91 - 0s - loss: 0.0089 - val_loss: 0.0071 - 348ms/epoch - 4ms/step
# Epoch 45/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0070 - 362ms/epoch - 4ms/step
# Epoch 46/50
# 91/91 - 0s - loss: 0.0090 - val_loss: 0.0070 - 371ms/epoch - 4ms/step
# Epoch 47/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0072 - 369ms/epoch - 4ms/step
# Epoch 48/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0072 - 378ms/epoch - 4ms/step
# Epoch 49/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0071 - 379ms/epoch - 4ms/step
# Epoch 50/50
# 91/91 - 0s - loss: 0.0088 - val_loss: 0.0070 - 378ms/epoch - 4ms/step

# %%
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
print(f'Mean Absolute Error: {mae}')
# Out:
# 23/23 [==============================] - 0s 2ms/step
# Mean Squared Error: 0.007031424547581284
# Mean Absolute Error: 0.06595846344950852

# %%
model.save(r"models/avg_temp_lstm_model.h5")
# Out:
# d:\Python\Lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test, label='Actual')
plt.plot(y_pred, label='Predicted', alpha=0.7)
plt.title('Actual vs Predicted')
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.legend()
plt.savefig('actual_vs_predicted.png')
plt.show()
